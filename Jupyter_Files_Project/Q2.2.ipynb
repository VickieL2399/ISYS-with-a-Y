# %%
#Is there a premium

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_sale_data = pd.read_csv('./Online_Cars_Sale_Marketplace_Data.csv')

# %%
car_sale_data
# Out:
#       Year     Make                   Model Used/New    Price  ConsumerRating  \
# 0     2019   Toyota               Sienna SE     Used  $39,998             4.6
# 1     2018     Ford            F-150 Lariat     Used  $49,985             4.8
# 2     2017      RAM            1500 Laramie     Used  $41,860             4.7
# 3     2021    Honda         Accord Sport SE     Used  $28,500             5.0
# 4     2020    Lexus                  RX 350     Used  $49,000             4.8
# ...    ...      ...                     ...      ...      ...             ...
# 9374  2019   Subaru  Crosstrek 2.0i Premium     Used  $27,374             4.7
# 9375  2019     Audi         Q8 3.0T Premium     Used  $61,998             4.8
# 9376  2017    Buick         Enclave Leather     Used  $26,944             4.8
# 9377  2019   Subaru        Forester Premium     Used  $28,568             4.7
# 9378  2019  Hyundai   Santa Fe Ultimate 2.4     Used  $32,091             4.8
#
# ...

# %%
car_sale_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9374 entries, 0 to 9378
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   9374 non-null   int64
#  1   Make                   9374 non-null   object
#  2   Model                  9374 non-null   object
#  3   Used/New               9374 non-null   object
#  4   Price                  9374 non-null   int64
#  5   ConsumerRating         9374 non-null   float64
#  6   ConsumerReviews        9374 non-null   int64
#  7   SellerType             9374 non-null   object
#  8   SellerName             9374 non-null   object
#  9   SellerRating           9374 non-null   float64
#  10  SellerReviews          9374 non-null   int64
#  11  StreetName             9374 non-null   object
#  12  State                  9374 non-null   object
#  13  Zipcode                9374 non-null   object
# ...

# %%
# Load the database into a pandas dataframe
car_sale_data = pd.read_csv('./Online_Cars_Sale_Marketplace_Data.csv')

# Remove the dollar sign from the 'Price' column
car_sale_data['Price'] = car_sale_data['Price'].str.replace('$', '')

# Remove the comma from the 'Price' column
car_sale_data['Price'] = car_sale_data['Price'].str.replace(',', '')

# Remove the "Not Priced" from the 'Price' column
car_sale_data = car_sale_data[car_sale_data['Price']!= 'Not Priced']

# Turn 'Price' into all ints
car_sale_data['Price'] = car_sale_data['Price'].astype(int)


car_sale_data
# Out:
# /var/folders/s0/6td_1_5n7m94_g09f8k7mnz00000gn/T/ipykernel_20062/3243639420.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   car_sale_data['Price'] = car_sale_data['Price'].str.replace('$', '')
#       Year     Make                   Model Used/New  Price  ConsumerRating  \
# 0     2019   Toyota               Sienna SE     Used  39998             4.6
# 1     2018     Ford            F-150 Lariat     Used  49985             4.8
# 2     2017      RAM            1500 Laramie     Used  41860             4.7
# 3     2021    Honda         Accord Sport SE     Used  28500             5.0
# 4     2020    Lexus                  RX 350     Used  49000             4.8
# ...    ...      ...                     ...      ...    ...             ...
# 9374  2019   Subaru  Crosstrek 2.0i Premium     Used  27374             4.7
# ...

# %%
car_sale_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9374 entries, 0 to 9378
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   9374 non-null   int64
#  1   Make                   9374 non-null   object
#  2   Model                  9374 non-null   object
#  3   Used/New               9374 non-null   object
#  4   Price                  9374 non-null   int64
#  5   ConsumerRating         9374 non-null   float64
#  6   ConsumerReviews        9374 non-null   int64
#  7   SellerType             9374 non-null   object
#  8   SellerName             9374 non-null   object
#  9   SellerRating           9374 non-null   float64
#  10  SellerReviews          9374 non-null   int64
#  11  StreetName             9374 non-null   object
#  12  State                  9374 non-null   object
#  13  Zipcode                9374 non-null   object
# ...

# %%
car_sale_data.sort_values(by=["Price"])[["Price"]]
# Out:
#        Price
# 2593    2300
# 6060    3995
# 811     3995
# 424     3999
# 1048    4250
# ...      ...
# 7022  285000
# 2181  309888
# 1626  349995
# 2888  409999
# 7943  449996
#
# [9374 rows x 1 columns]

# %%
countDealer = len(car_sale_data[car_sale_data['SellerType'] == 'Dealer'])
print("The number of Dealers are:",countDealer)
# Out:
# The number of Dealers are: 9334

# %%
countPrivate = len(car_sale_data[car_sale_data['SellerType'] == 'Private'])
print("The number of Private are:",countPrivate)
# Out:
# The number of Private are: 40

# %%
car_sale_data.sort_values(by=["Price","Make","Model"])[["Price","Make","Model"]]
# Out:
#        Price           Make              Model
# 2593    2300      Chevrolet          Impala LT
# 811     3995           Ford           Focus SE
# 6060    3995        Hyundai        Elantra GLS
# 424     3999          Lexus   ES 300 Base (A5)
# 1048    4250       Chrysler        200 Limited
# ...      ...            ...                ...
# 7022  285000    Lamborghini          Urus Base
# 2181  309888        Porsche            911 GT3
# 1626  349995    Lamborghini  Aventador LP700-4
# 2888  409999  Mercedes-Benz      G-Class G 550
# 7943  449996  Mercedes-Benz      AMG G 63 Base
#
# [9374 rows x 3 columns]

# %%
sns.barplot(x=car_sale_data['Price'], y=car_sale_data['Make']);

# %%
honda_priv_sales = car_sale_data[(car_sale_data['Make'] == 'Honda') & (car_sale_data['SellerType'] == 'Private')]

# Calculate the average price of Honda dealer sales
average_price_p = honda_priv_sales['Price'].mean()

# Print the result
print('The average mean price of Hondas sold by Private is: $', round(average_price_p, 2))
# Out:
# The average mean price of Hondas sold by Private is: $ 27816.33

# %%
honda_priv_sales = car_sale_data[(car_sale_data['SellerType'] == 'Private')]

# Calculate the average price of Honda dealer sales
average_price_p = honda_priv_sales['Price'].mean()

# Print the result
print('The average mean price of cars sold by Private is: $', round(average_price_p, 2))
# Out:
# The average mean price of cars sold by Private is: $ 36515.07

# %%
honda_dealer_sales = car_sale_data[(car_sale_data['Make'] == 'Honda') & (car_sale_data['SellerType'] == 'Dealer')]

# Calculate the average price of Honda dealer sales
average_price_d = honda_dealer_sales['Price'].mean()

# Print the result
print('The average mean price of Hondas sold by dealers is: $', round(average_price_d, 2))
# Out:
# The average mean price of Hondas sold by dealers is: $ 31658.53

# %%
honda_dealer_sales = car_sale_data[(car_sale_data['SellerType'] == 'Dealer')]

# Calculate the average price of Honda dealer sales
average_price_d = honda_dealer_sales['Price'].mean()

# Print the result
print('The average mean price of cars sold by dealers is: $', round(average_price_d, 2))
# Out:
# The average mean price of cars sold by dealers is: $ 39848.57

# %%
honda_priv_sales = car_sale_data[(car_sale_data['Make'] == 'Honda') & (car_sale_data['SellerType'] == 'Private')]
honda_priv_sales
# Out:
#       Year   Make                          Model Used/New  Price  \
# 31    2016  Honda                   Odyssey EX-L     Used  28999
# 1504  2020  Honda  Odyssey EX-L w/Navigation/RES     Used  35500
# 2428  2017  Honda                Accord Sport SE     Used  18950
#
#       ConsumerRating  ConsumerReviews SellerType SellerName  SellerRating  \
# 31               4.7              100    Private    Darshan           4.7
# 1504             4.7               53    Private        Ray           3.5
# 2428             4.8              572    Private    Richard           4.5
#
#       ...  InteriorColor         Drivetrain MinMPG MaxMPG       FuelType  \
# 31    ...          Beige  Front-wheel Drive     19     28  Gasoline Fuel
# 1504  ...           Gray  Front-wheel Drive     19     28  Gasoline Fuel
# 2428  ...          Black  Front-wheel Drive     23     32  Gasoline Fuel
#
#       Transmission                                         Engine  \
# ...

# %%
honda_dealer_sales = car_sale_data[(car_sale_data['Make'] == 'Honda') & (car_sale_data['SellerType'] == 'Dealer')]
honda_dealer_sales
# Out:
#       Year   Make                      Model         Used/New  Price  \
# 3     2021  Honda            Accord Sport SE             Used  28500
# 6     2017  Honda                    HR-V LX             Used  20995
# 8     2021  Honda  Pilot Touring 8-Passenger             Used  44299
# 30    2019  Honda               Odyssey EX-L             Used  38347
# 36    2019  Honda               Odyssey EX-L             Used  38900
# ...    ...    ...                        ...              ...    ...
# 9350  2021  Honda                  CR-V EX-L             Used  37890
# 9366  2019  Honda                 Pilot EX-L             Used  35225
# 9368  2021  Honda          Accord Sport 1.5T  Honda Certified  29500
# 9370  2019  Honda                  CR-V EX-L             Used  33277
# 9373  2019  Honda                  CR-V EX-L             Used  31999
#
#       ConsumerRating  ConsumerReviews SellerType  \
# 3                5.0               36     Dealer
# ...

# %%
honda = car_sale_data[(car_sale_data['Make'] == 'Honda' )]



sns.scatterplot(data=honda, x='Year', y='Price', hue='SellerType',);
