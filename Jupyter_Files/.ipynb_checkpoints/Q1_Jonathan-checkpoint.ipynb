# %%
#What is the most popular car listing on this platform?

# 2021 HYUNDAI KONA SEL PLUS
# OR
# 2018 FORD F-150 XL

# %%
# !pip install sqlalchemy
# !pip install matplotlib
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

conn = sqlite3.connect("car_sales.db")

df = pd.read_csv("Online_Cars_Sale_Marketplace_Data.csv")
df.to_sql("car_sales", conn, if_exists="replace", index=False)
# Out:
# Requirement already satisfied: sqlalchemy in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (2.0.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from sqlalchemy) (4.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from sqlalchemy) (2.0.2)
# Requirement already satisfied: matplotlib in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.20 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/jonathan_terada/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# 9379

# %%
#Based on highest Consumer Rating > Consumer Reviews > Total Listings
q1 = """
SELECT Year, 
Make, 
Model, 
AVG(ConsumerRating) AS ConsumerRating, 
ConsumerReviews, 
SellerRating, 
COUNT(Model) AS total_listings
FROM car_sales
GROUP BY Model
ORDER BY ConsumerRating DESC, ConsumerReviews DESC, total_listings ASC
LIMIT 20
;
"""

pd.read_sql(q1,conn)
# Out:
#     Year           Make                       Model  ConsumerRating  \
# 0   2021        Hyundai               Kona SEL Plus             5.0
# 1   2021          Honda           Accord Sport 2.0T             5.0
# 2   2018       Cadillac         Escalade ESV Luxury             5.0
# 3   2020  Mercedes-Benz        E-Class E 450 4MATIC             5.0
# 4   2019  Mercedes-Benz              GLS 450 4MATIC             5.0
# 5   2019  Mercedes-Benz     AMG GLE 43 4MATIC Coupe             5.0
# 6   2020       Cadillac           Escalade Platinum             5.0
# 7   2016       INFINITI                    Q70 3.7X             5.0
# 8   2020            GMC          Sierra 3500 Denali             5.0
# 9   2021           Audi        Q3 45 S line Premium             5.0
# 10  2020           Ford      Fusion Hybrid Titanium             5.0
# 11  2022        Hyundai                  IONIQ 5 SE             5.0
# 12  2020     Mitsubishi                Mirage G4 LE             5.0
# 13  2020           Audi  Q7 55 quattro Premium Plus             5.0
# 14  2018            BMW                     M6 Base             5.0
# 15  2020          Lexus                RX 350L Base             5.0
# 16  2019            BMW                       750 i             5.0
# 17  2020          Volvo             S90 T6 R-Design             5.0
# 18  2020           Ford            Transit-250 Base             5.0
# 19  2019            BMW               M850 i xDrive             5.0
#
#     ConsumerReviews  SellerRating  total_listings
# 0                48           4.8               1
# 1                36           4.0               2
# 2                11           4.8               6
# 3                10           4.8               1
# 4                10           4.6               2
# 5                10           4.5              21
# 6                 9           4.5               3
# 7                 8           4.7               1
# 8                 8           4.4               1
# 9                 8           4.6              16
# 10                6           4.3               2
# 11                6           4.5               2
# 12                6           4.8               2
# 13                6           4.9               2
# 14                5           4.6               1
# 15                5           4.6               1
# 16                5           4.5               2
# 17                5           4.3               2
# 18                5           4.8               4
# 19                5           4.3               7

# %%
from sqlalchemy import create_engine

query = """
SELECT Model,
AVG(ConsumerRating) AS ConsumerRating, 
ConsumerReviews
FROM car_sales
GROUP BY Model
ORDER BY ConsumerRating DESC, ConsumerReviews DESC
LIMIT 20
"""

df2 = pd.read_sql(query,conn)
plot = df2.plot.barh(title="Most Popular Car v1", x="Model");

# %%
#Based on highest Consumer Review > Consumer Rating > Total Listings
q2 = """
SELECT Year, 
Make, 
Model, 
CAST(AVG(ConsumerRating) AS DECIMAL (10,2)) AS ConsumerRating, 
ConsumerReviews, 
SellerRating, 
COUNT(*) AS total_listings
FROM car_sales
GROUP BY Model
ORDER BY ConsumerReviews DESC, ConsumerRating DESC, total_listings ASC
LIMIT 20
;
"""

pd.read_sql(q2,conn)
# Out:
#     Year     Make                   Model  ConsumerRating  ConsumerReviews  \
# 0   2018     Ford                F-150 XL        4.800000              817
# 1   2018     Ford            F-150 Lariat        4.785714              817
# 2   2017    Honda            CR-V Touring        4.761905              803
# 3   2018   Toyota               Camry XLE        4.750000              781
# 4   2018   Toyota                RAV4 XLE        4.750704              770
# 5   2018   Toyota            RAV4 Limited        4.709677              770
# 6   2017    Honda                Civic EX        4.800000              743
# 7   2018    Honda     Accord Touring 2.0T        4.933333              652
# 8   2018    Honda        Accord EX-L 2.0T        4.800000              652
# 9   2018    Honda               Accord EX        4.766667              652
# 10  2017  Hyundai               Tucson SE        4.706667              623
# 11  2017      Kia                Forte LX        4.762500              593
# 12  2018     Ford                Escape S        4.625000              578
# 13  2017    Honda               Accord LX        4.766667              572
# 14  2019     Jeep  Cherokee Latitude Plus        4.644444              568
# 15  2017   Nissan                 Rogue S        4.693750              547
# 16  2018    Honda                Civic LX        4.867187              546
# 17  2018    Honda              Civic EX-T        4.800000              546
# 18  2019    Honda               CR-V EX-L        4.804233              540
# 19  2019    Honda                 CR-V EX        4.801299              540
#
#     SellerRating  total_listings
# 0            4.4               7
# 1            4.8              56
# 2            4.7              21
# 3            4.2               2
# 4            3.3              71
# 5            4.7              31
# 6            4.2              11
# 7            4.6               3
# 8            4.7               3
# 9            4.9               3
# 10           4.5              15
# 11           4.5               8
# 12           4.3               4
# 13           4.7               3
# 14           4.7               9
# 15           4.9              16
# 16           4.8              64
# 17           4.4               2
# 18           4.9             189
# 19           3.7              77

# %%
from sqlalchemy import create_engine

query2 = """
SELECT Model,
AVG(ConsumerRating)*50 AS ConsumerRating, 
ConsumerReviews
FROM car_sales
GROUP BY Model
ORDER BY ConsumerReviews DESC, ConsumerRating DESC
LIMIT 20
"""

df2 = pd.read_sql(query2,conn)
plot = df2.plot.barh(title="Most Popular Car v2", x="Model");

# %%
#Define what is a popular car listing?

# - HIGHEST CONSUMER RATING: This would identify the car listing that has the highest average rating from consumers,
#   and would be a good metric for identifying the car that is the most highly-regarded by buyers.

# - HIGHEST CONSUMER REVIEW + CONSUMER RATING: This would identify the car listing that has the most reviews from consumers,
#   and would be a good metric for identifying the car that has generated the most interest or engagement from buyers.

# - TOTAL CAR LISTINGS: This would identify the number of cars available for sale by the marketplace,
#   and would be a good metric for identifying how in-demand a car is. The more cars available, the least in-demand it may be.

# - COUPLING METRICS: This would be a more precise identifier to pinpointing which car is most popular, 
#   depending on the defintion we choose.

# %%
#How to uniquely define a type of car? By country made, brand year, etc (1).
q3 = """
SELECT DISTINCT(model), Make
FROM car_sales
ORDER BY Make, Model
;
"""

pd.read_sql(q3,conn)
# Out:
#                                 Model   Make
# 0                                 ILX  Acura
# 1       ILX Premium & A-SPEC Packages  Acura
# 2                 ILX Premium Package  Acura
# 3               ILX w/AcuraWatch Plus  Acura
# 4                   ILX w/Premium Pkg  Acura
# ...                               ...    ...
# 1299  XC90 T6 Inscription 6 Passenger  Volvo
# 1300  XC90 T6 Inscription 7 Passenger  Volvo
# 1301                 XC90 T6 Momentum  Volvo
# 1302     XC90 T6 Momentum 7 Passenger  Volvo
# 1303                 XC90 T6 R-Design  Volvo
#
# [1304 rows x 2 columns]

# %%
#How to uniquely define a type of car? By country made, brand year, etc (2).
q4 = """
SELECT make, model
FROM car_sales
GROUP BY model
ORDER BY Make, Model
;
"""
pd.read_sql(q4,conn)
# Out:
#        Make                            Model
# 0     Acura                              ILX
# 1     Acura    ILX Premium & A-SPEC Packages
# 2     Acura              ILX Premium Package
# 3     Acura            ILX w/AcuraWatch Plus
# 4     Acura                ILX w/Premium Pkg
# ...     ...                              ...
# 1299  Volvo  XC90 T6 Inscription 6 Passenger
# 1300  Volvo  XC90 T6 Inscription 7 Passenger
# 1301  Volvo                 XC90 T6 Momentum
# 1302  Volvo     XC90 T6 Momentum 7 Passenger
# 1303  Volvo                 XC90 T6 R-Design
#
# [1304 rows x 2 columns]
